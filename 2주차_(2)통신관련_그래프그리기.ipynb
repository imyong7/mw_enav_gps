# %% [markdown]
# # Basic Signal Examples (Colab)
#
# This notebook demonstrates very basic signals with plots:
# 1. **Sine curve**
# 2. **Cosine curve**
# 3. **Sine + Cosine**
# 4. **Analog signal example**
# 5. **Digital signal example**

# %%
# 코드 입력하기

# %% [markdown]
# ## 1. Sine curve

# %%
# 코드 입력하기

# %% [markdown]
# ## 2. Cosine curve

# %%
# 코드 입력하기

# %% [markdown]
# ## 3. Sine + Cosine

# %%
# 코드 입력하기

# %% [markdown]
# ## 4. Analog signal example

# %%
# 코드 입력하기

# %% [markdown]
# ## 5. Digital signal example

# %%
# 코드 입력하기

# %% [markdown]
# ## 6. Comparison of sine graph according to frequency

# %%
# 코드 입력하기

# %% [markdown]
# ## 7. Check the bandwidth of the signal

# %%
# 코드 입력하기
