# %% [markdown]
# #0.사전 세팅

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # 1. 좌표와 위치 - 좌표(Coordinates)

# %%
# Example point
x, y = 3, 3

# %% [markdown]
# #1. 좌표와 위치 - 상대적 위치(Relative Position)

# %%
# Reference point (School)
school = (2, 2)

# Relative positions (Store, Cafe, Library)
store = (4, 2)
cafe = (2, 4)
library = (1, 3)

# %% [markdown]
# #2. 방위와 거리 - 방위표

# %%
# Create figure

# %% [markdown]
# #2. 방위와 거리 - 거리(Distance)

# %%
# Points
A = (0, 0)
B = (6, 4)

# Path points (simulating a road with bends)
path_x = [0, 2, 2, 4, 6]
path_y = [0, 0, 2, 4, 4]

# %% [markdown]
# #2. 방위와 거리 - 유클리드 거리(Euclidean Distance)

# %%
# Points
A = (1, 1)
B = (5, 4)
# Out:
# /tmp/ipython-input-2269306478.py:18: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([A[0], B[0]], [A[1], A[1]], 'b-', linestyle="--")
# /tmp/ipython-input-2269306478.py:19: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot([B[0], B[0]], [A[1], B[1]], 'b-', linestyle="--")

# %% [markdown]
# #3. 시간과 공간 - 시간(Time)

# %%
# 위성 위치 (단순히 2D 평면에서 표현)
satellites = [(0, 8), (8, 8), (4, 10)]
receiver = (4, 0)

# %% [markdown]
# #3. 시간과 공간 - 공간(Space, 2D)

# %%
# Define some points in space (e.g., landmarks)
landmarks = {
    "School": (2, 2),
    "Library": (6, 2),
    "Cafe": (4, 5),
    "Park": (7, 6)
}

# %% [markdown]
# #3. 시간과 공간 - 공간(Space, 3D)

# %%
# Define landmarks in 3D space
landmarks_3d = {
    "School": (2, 2, 1),
    "Library": (6, 2, 2),
    "Cafe": (4, 5, 3),
    "Park": (7, 6, 1)
}
